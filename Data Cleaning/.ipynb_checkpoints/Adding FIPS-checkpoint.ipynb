# %%
#imports

import pandas as pd

# %%
#reading in data

PM2_2009_2014 = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/2009_2014.6_CA_PM2.5.csv")
PM10_2009_2014 = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/2009_2014.6_CA_PM10.csv")
PM2_2014_2021 = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/2014.6_2021_CA_PM2.5.csv")
PM10_2014_2021 = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/2014.6_2021_CA_PM10.csv")
census_commuting = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_COMMUTING TO WORK_2009-2021.csv")
census_education = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_EDUCATIONAL ATTAINMENT_2009-2021.csv")
census_employment = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_EMPLOYMENT STATUS _2009-2021.csv")
census_heating = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_HOUSE HEATING FUEL _2009-2021.csv")
census_income = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_INCOME AND BENEFITS_2009-2021.csv")
census_industry = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_INDUSTRY_2009-2021.csv")
census_occupation = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_OCCUPATION_2009-2021.csv")
census_poverty = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_PERCENTAGE under POVERTY LEVEL_2010-2021.csv")
census_race = pd.read_csv("/Users/mattthowell/Desktop/PIC_16B_Data/census_data_RACE_2009-2021.csv")

# %%
#let's do a case study of one of the air quality data frames.

PM2_2009_2014
# Out:
#         state_code  county_code  site_number  parameter_code  poc   latitude  \
# 0                6           75            5           88101    1  37.765946
# 1                6           75            5           88101    1  37.765946
# 2                6           75            5           88101    1  37.765946
# 3                6           75            5           88101    1  37.765946
# 4                6           75            5           88101    1  37.765946
# ...            ...          ...          ...             ...  ...        ...
# 860854           6           73         1006           88101    1  32.842318
# 860855           6           73         1006           88101    1  32.842318
# 860856           6           73         1006           88101    1  32.842318
# 860857           6           73         1006           88101    1  32.842318
# 860858           6           73         1006           88101    1  32.842318
#
#          longitude  datum                 parameter sample_duration_code  ...  \
# 0      -122.399044  WGS84  PM2.5 - Local Conditions                    7  ...
# 1      -122.399044  WGS84  PM2.5 - Local Conditions                    7  ...
# 2      -122.399044  WGS84  PM2.5 - Local Conditions                    7  ...
# 3      -122.399044  WGS84  PM2.5 - Local Conditions                    7  ...
# 4      -122.399044  WGS84  PM2.5 - Local Conditions                    7  ...
# ...            ...    ...                       ...                  ...  ...
# 860854 -116.768293  NAD83  PM2.5 - Local Conditions                    X  ...
# 860855 -116.768293  NAD83  PM2.5 - Local Conditions                    X  ...
# 860856 -116.768293  NAD83  PM2.5 - Local Conditions                    X  ...
# 860857 -116.768293  NAD83  PM2.5 - Local Conditions                    X  ...
# 860858 -116.768293  NAD83  PM2.5 - Local Conditions                    1  ...
#
#        method_code                                             method  \
# 0              145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 1              145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 2              145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 3              145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 4              145  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# ...            ...                                                ...
# 860854         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 860855         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 860856         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 860857         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 860858         170  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
#
#        local_site_name               site_address       state         county  \
# 0        San Francisco            10 ARKANSAS ST.  California  San Francisco
# 1        San Francisco            10 ARKANSAS ST.  California  San Francisco
# 2        San Francisco            10 ARKANSAS ST.  California  San Francisco
# 3        San Francisco            10 ARKANSAS ST.  California  San Francisco
# 4        San Francisco            10 ARKANSAS ST.  California  San Francisco
# ...                ...                        ...         ...            ...
# 860854          Alpine  2300 VICTORIA DR., ALPINE  California      San Diego
# 860855          Alpine  2300 VICTORIA DR., ALPINE  California      San Diego
# 860856          Alpine  2300 VICTORIA DR., ALPINE  California      San Diego
# 860857          Alpine  2300 VICTORIA DR., ALPINE  California      San Diego
# 860858          Alpine  2300 VICTORIA DR., ALPINE  California      San Diego
#
#                  city cbsa_code                               cbsa  \
# 0       San Francisco   41860.0  San Francisco-Oakland-Hayward, CA
# 1       San Francisco   41860.0  San Francisco-Oakland-Hayward, CA
# 2       San Francisco   41860.0  San Francisco-Oakland-Hayward, CA
# 3       San Francisco   41860.0  San Francisco-Oakland-Hayward, CA
# 4       San Francisco   41860.0  San Francisco-Oakland-Hayward, CA
# ...               ...       ...                                ...
# 860854         Alpine   41740.0             San Diego-Carlsbad, CA
# 860855         Alpine   41740.0             San Diego-Carlsbad, CA
# 860856         Alpine   41740.0             San Diego-Carlsbad, CA
# 860857         Alpine   41740.0             San Diego-Carlsbad, CA
# 860858         Alpine   41740.0             San Diego-Carlsbad, CA
#
#         date_of_last_change
# 0                2021-11-08
# 1                2021-11-08
# 2                2021-11-08
# 3                2021-11-08
# 4                2021-11-08
# ...                     ...
# 860854           2023-02-05
# 860855           2023-02-05
# 860856           2023-02-05
# 860857           2023-02-05
# 860858           2023-01-12
#
# [860859 rows x 32 columns]

# %%
#it looks like the county code is in the county_code column. it is our goal to create FIPS codes out of these county codes.
    #FIPS codes uniquely identify counties by appending a 3-digit county code to a 2-digit state code.
    #we are only working with California data, so we can always use "06" for the state code.
    #problem: we need to edit the county codes to all be 3 digits, with 0s filling in the first entries if necessary
    #let's write a function for that
    
def fips_column(df, county_column_name):
    j = 0
    df["fips"] = df[county_column_name]
    for i in df[county_column_name]:
        if len(f"{i}") == 1:
            df["fips"][j] = "06" + "00" + f"{i}"
        elif len(f"{i}") == 2:
            df["fips"][j] = "06" + "0" + f"{i}"
        else:
            df["fips"][j] = "06" + f"{i}"
        j += 1

# %%
fips_column(PM2_2009_2014, "county_code")
fips_column(PM10_2009_2014, "county_code")
fips_column(PM2_2014_2021, "county_code")
fips_column(PM10_2014_2021, "county_code")
# Out:
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3813695670.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "0" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3813695670.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "0" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3813695670.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "0" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3813695670.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "0" + f"{i}"

# %%
#let's look at the census data

census_commuting
# Out:
#                              NAME  \
# 0      Alameda County, California
# 1       Alpine County, California
# 2       Amador County, California
# 3        Butte County, California
# 4    Calaveras County, California
# ..                            ...
# 749     Tulare County, California
# 750   Tuolumne County, California
# 751    Ventura County, California
# 752       Yolo County, California
# 753       Yuba County, California
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over  \
# 0                                               690624
# 1                                                  512
# 2                                                13943
# 3                                                88383
# 4                                                18855
# ..                                                 ...
# 749                                             181690
# 750                                              20686
# 751                                             402256
# 752                                              99145
# 753                                              32181
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over  \
# 0                                               690624
# 1                                                  512
# 2                                                13943
# 3                                                88383
# 4                                                18855
# ..                                                 ...
# 749                                             181690
# 750                                              20686
# 751                                             402256
# 752                                              99145
# 753                                              32181
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over   Car, truck, or van — drove alone  \
# 0                                               459728
# 1                                                  341
# 2                                                11346
# 3                                                67186
# 4                                                14732
# ..                                                 ...
# 749                                             142930
# 750                                              16142
# 751                                             306123
# 752                                              65426
# 753                                              25805
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over   Car, truck, or van — drove alone  \
# 0                                                 66.6
# 1                                                 66.6
# 2                                                 81.4
# 3                                                 76.0
# 4                                                 78.1
# ..                                                 ...
# 749                                               78.7
# 750                                               78.0
# 751                                               76.1
# 752                                               66.0
# 753                                               80.2
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over   Car, truck, or van — carpooled  \
# 0                                                73513
# 1                                                   60
# 2                                                 1233
# 3                                                 8835
# 4                                                 2145
# ..                                                 ...
# 749                                              24399
# 750                                               1665
# 751                                              38410
# 752                                               8413
# 753                                               3497
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over   Car, truck, or van — carpooled  \
# 0                                                 10.6
# 1                                                 11.7
# 2                                                  8.8
# 3                                                 10.0
# 4                                                 11.4
# ..                                                 ...
# 749                                               13.4
# 750                                                8.0
# 751                                                9.5
# 752                                                8.5
# 753                                               10.9
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over   Public transportation (excluding taxicab)  \
# 0                                                78609
# 1                                                    0
# 2                                                  117
# 3                                                  981
# 4                                                  226
# ..                                                 ...
# 749                                                871
# 750                                                 88
# 751                                               3379
# 752                                               3576
# 753                                                201
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over   Public transportation (excluding taxicab)  \
# 0                                                 11.4
# 1                                                  0.0
# 2                                                  0.8
# 3                                                  1.1
# 4                                                  1.2
# ..                                                 ...
# 749                                                0.5
# 750                                                0.4
# 751                                                0.8
# 752                                                3.6
# 753                                                0.6
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over    Walked  \
# 0                                                24589
# 1                                                   48
# 2                                                  449
# 3                                                 3431
# 4                                                  392
# ..                                                 ...
# 749                                               2609
# 750                                                621
# 751                                               6431
# 752                                               2140
# 753                                                523
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over    Walked  \
# 0                                                  3.6
# 1                                                  9.4
# 2                                                  3.2
# 3                                                  3.9
# 4                                                  2.1
# ..                                                 ...
# 749                                                1.4
# 750                                                3.0
# 751                                                1.6
# 752                                                2.2
# 753                                                1.6
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over   Other means  \
# 0                                                21652
# 1                                                    4
# 2                                                  196
# 3                                                 3197
# 4                                                  168
# ..                                                 ...
# 749                                               1991
# 750                                                274
# 751                                               4845
# 752                                               7194
# 753                                                401
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over   Other means  \
# 0                                                  3.1
# 1                                                  0.8
# 2                                                  1.4
# 3                                                  3.6
# 4                                                  0.9
# ..                                                 ...
# 749                                                1.1
# 750                                                1.3
# 751                                                1.2
# 752                                                7.3
# 753                                                1.2
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over    Worked from home  \
# 0                                                32533
# 1                                                   59
# 2                                                  602
# 3                                                 4753
# 4                                                 1192
# ..                                                 ...
# 749                                               8890
# 750                                               1896
# 751                                              43068
# 752                                              12396
# 753                                               1754
#
#      Percentage  COMMUTING TO WORK   Workers 16 years and over    Worked from home  \
# 0                                                  4.7
# 1                                                 11.5
# 2                                                  4.3
# 3                                                  5.4
# 4                                                  6.3
# ..                                                 ...
# 749                                                4.9
# 750                                                9.2
# 751                                               10.7
# 752                                               12.5
# 753                                                5.5
#
#      Estimate   COMMUTING TO WORK   Workers 16 years and over   Mean travel time to work (minutes)  \
# 0                                                 27.9
# 1                                                 25.0
# 2                                                 29.3
# 3                                                 20.8
# 4                                                 35.7
# ..                                                 ...
# 749                                               22.5
# 750                                               29.3
# 751                                               26.8
# 752                                               24.0
# 753                                               29.5
#
#     Percentage  COMMUTING TO WORK   Workers 16 years and over   Mean travel time to work (minutes)  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 749                                         -888888888
# 750                                         -888888888
# 751                                         -888888888
# 752                                         -888888888
# 753                                         -888888888
#
#      state  county  Year
# 0        6       1  2009
# 1        6       3  2009
# 2        6       5  2009
# 3        6       7  2009
# 4        6       9  2009
# ..     ...     ...   ...
# 749      6     107  2021
# 750      6     109  2021
# 751      6     111  2021
# 752      6     113  2021
# 753      6     115  2021
#
# [754 rows x 20 columns]

# %%
fips_column(census_commuting, "county")
fips_column(census_education, "county")
fips_column(census_employment, "county")
fips_column(census_heating, "county")
fips_column(census_income, "county")
fips_column(census_industry, "county")
fips_column(census_occupation, "county")
fips_column(census_poverty, "county")
fips_column(census_race, "county")
# Out:
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
# /var/folders/v9/2tqxl6c10dx5ddj96lxyrw6w0000gn/T/ipykernel_10337/3435643342.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fips"][j] = "06" + "00" + f"{i}"
