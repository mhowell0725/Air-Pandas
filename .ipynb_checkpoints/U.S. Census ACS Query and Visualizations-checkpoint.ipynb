# %% [markdown]
# Note for imports: there is a really useful package I found called `censusdata`. You can find the documentation linked [here](https://jtleider.github.io/censusdata/api.html#module-censusdata.censusgeo).

# %%
import pandas as pd
import censusdata

# %% [markdown]
# # 1. Recreating Query Functions
#
# Previously, we created an ACS5 query function that returned data for all zip codes in LA county. I provide that function here.

# %%
def query_acs5(year):
    
    '''
    Query 5-year ACS racial/ethnic and median income data for all zip codes in LA county between 2011 and 2019.
    
    Args:
        year: year for which we want to gether data.
        
    Returns:
        a pandas dataframe with the desired data
    '''
    
    zip_codes_df = pd.read_csv('la_county_zip_codes.csv')
    zip_codes_df
    
    zip_codes = zip_codes_df["ZIP"]
    
    zip_codes = zip_codes.tolist()

    #querying in the data from the U.S. Census again
    data = pd.read_json(f"https://api.census.gov/data/{year}/acs/acs5?get=B01003_001E,B02001_002E,B02001_003E,B02001_004E,B02001_005E,B02001_006E,B02001_007E,B02001_008E,B03001_003E,B19013_001E&for=zip%20code%20tabulation%20area:*&in=state:06")

    #replacing the column titles with the first row
    data.columns = data.iloc[0]

    #cleaning up the data
    data = data.drop([0])
    data["zip code tabulation area"] = data["zip code tabulation area"].astype(int)

    data = data[data["zip code tabulation area"].isin(zip_codes)]
    data.columns = ["pop_total", "pop_white", "pop_black","pop_aian", "pop_asian", "pop_nhpi", "pop_other_race", "pop_two_plus_races","pop_hispanic_latino", "income_median_household", "state_code", "zip_code"]
    
    return data

# %% [markdown]
# After creating this function, we determined that it would not be feasible to do our project at the zip code level. As a result, we had to modify our project to examine county-level data. This document aims to modify the above function to query data at this level.

# %%
def query_ACS5(year):
    '''
    query race, ethnicity, and income data from ACS5 for years ranging from 2009 to 2021
    
    Args:
        year: an integer between 2009 and 2021
        
    Returns:
        a pandas dataframe
    '''
    
    # Define the desired variables
    variables = [
        'B01003_001E',  # Total population
        'B02001_002E',  # Total population - White alone
        'B02001_003E',  # Total population - Black or African American alone
        'B02001_004E',  # Total population - American Indian and Alaska Native alone
        'B02001_005E',  # Total population - Asian alone
        'B02001_006E',  # Total population - Native Hawaiian and Other Pacific Islander alone
        'B02001_007E',  # Total population - Some other race alone
        'B02001_008E',  # Total population - Two or more races
        'B03001_003E',  # Total population - Hispanic or Latino
        'B19013_001E',  # Median household income
    ]

    # Set the state
    state = '06'

    # Get all county codes for California
    counties = censusdata.geographies(censusdata.censusgeo([('state', state), ('county', '*')]), "acs5", year = year)

    # Query data for each county
    data = censusdata.download('acs5', year, censusdata.censusgeo([('state', state), ('county', '*')]), variables)

    county_name = list(range(len(data.index)))
    FIPS = list(range(len(data.index)))
    i = 0
    for county_code, county_data in data.iterrows():
        county_name[i] = [k for k,v in counties.items() if v == county_code][0]
        FIPS[i] = county_code.params()[0][1] + county_code.params()[1][1]
        i += 1
    
    data.index = county_name
    data["FIPS"] = FIPS
    
    return data

# %%
data = query_ACS5(2020)
data
# Out:
#                                     B01003_001E  B02001_002E  B02001_003E
# Alameda County, California              1661584       631037       171922  \
# Alpine County, California                  1159          663           10
# Butte County, California                 223344       178568         3866
# Colusa County, California                 21491        17012          330
# Contra Costa County, California         1147788       608789        98569
# El Dorado County, California             190345       164552         1586
# Fresno County, California                990204       597574        46182
# Humboldt County, California              136101       107151         1558
# Imperial County, California              180580       102305         4716
# Kern County, California                  892458       603368        48530
# Kings County, California                 151090        95764         9820
# Lassen County, California                 30600        24181         2713
# Madera County, California                155925        94643         4919
# Marin County, California                 259441       199068         6001
# Mariposa County, California               17319        15134          266
# Mendocino County, California              87110        69709          424
# Merced County, California                273661       139469         8190
# Modoc County, California                   8853         7801          123
# Monterey County, California              432977       209849        11162
# Napa County, California                  138572        98614         2862
# Nevada County, California                 99417        91597          410
# Orange County, California               3170345      1826960        54061
# Placer County, California                391799       314938         6310
# Plumas County, California                 18844        16679          279
# Riverside County, California            2437864      1358654       157908
# Sacramento County, California           1537948       839349       148884
# San Benito County, California             61547        45157          523
# San Bernardino County, California       2162532      1212480       176523
# San Diego County, California            3323970      2213608       164042
# San Francisco County, California         874784       392476        44930
# San Joaquin County, California           751615       387165        53116
# San Luis Obispo County, California       282517       233297         4865
# San Mateo County, California             765623       369924        18104
# Santa Clara County, California          1924379       801381        47379
# Santa Cruz County, California            273170       195781         3472
# Sierra County, California                  2898         2722            3
# Solano County, California                444538       225258        60991
# Sonoma County, California                496801       360200         8266
# Sutter County, California                 96315        61307         1894
# Tehama County, California                 64176        53987          420
# Tulare County, California                463955       309798         7606
# Tuolumne County, California               54147        46905         1007
# Yolo County, California                  218774       145299         5694
# Yuba County, California                   77524        56990         2632
# Mono County, California                   14395        11966           81
# Amador County, California                 39023        33040          931
# Calaveras County, California              45828        40058          450
# Del Norte County, California              27692        20002          747
# Glenn County, California                  28060        22478          218
# Inyo County, California                   17930        13705           96
# Lake County, California                   64276        48712         1583
# Los Angeles County, California         10040682      4795186       810286
# Santa Barbara County, California         444895       319547         8474
# Shasta County, California                179267       152586         1912
# Siskiyou County, California               43516        36195          668
# Stanislaus County, California            546235       384703        16961
# Trinity County, California                12541        10694           65
# Ventura County, California               845599       637686        15422
#
#                                     B02001_004E  B02001_005E  B02001_006E
# Alameda County, California                11037       519249        13648  \
# Alpine County, California                   360            6            4
# Butte County, California                   2628        10743          717
# Colusa County, California                   239          201           32
# Contra Costa County, California            5191       200159         5676
# El Dorado County, California               1312         9111          479
# Fresno County, California                 11604       105302         1518
# Humboldt County, California                6162         3948          508
# Imperial County, California                2111         2599          241
# Kern County, California                    8462        43381         1380
# Kings County, California                   2232         5626          190
# Lassen County, California                   794          471          256
# Madera County, California                  2503         3362          159
# Marin County, California                    673        15060          361
# Mariposa County, California                 392          186           62
# Mendocino County, California               3789         1740          137
# Merced County, California                  2885        20881          744
# Modoc County, California                    313          169            7
# Monterey County, California                3072        25186         2104
# Napa County, California                     961        10485          261
# Nevada County, California                   496         1108          150
# Orange County, California                 15552       667534         9497
# Placer County, California                  2204        31938          910
# Plumas County, California                   350          232           29
# Riverside County, California              18852       164464         7915
# Sacramento County, California              9505       256464        17028
# San Benito County, California               527         1745           63
# San Bernardino County, California         18369       159917         6788
# San Diego County, California              24373       398526        13727
# San Francisco County, California           3800       300339         3179
# San Joaquin County, California             4695       119446         4597
# San Luis Obispo County, California         2383        10559          258
# San Mateo County, California               3917       225027         9611
# Santa Clara County, California             9990       724855         6949
# Santa Cruz County, California              1708        13563          484
# Sierra County, California                    69            0            0
# Solano County, California                  2531        69169         4212
# Sonoma County, California                  4441        21239         1614
# Sutter County, California                  1061        15997          588
# Tehama County, California                   865         1090           18
# Tulare County, California                  5955        17310          618
# Tuolumne County, California                 948          753          146
# Yolo County, California                    1420        31584         1018
# Yuba County, California                    1030         5631          310
# Mono County, California                     407          633            0
# Amador County, California                   276          375           30
# Calaveras County, California                518          864           18
# Del Norte County, California               1943          880           50
# Glenn County, California                    631          877           12
# Inyo County, California                    1924          279           37
# Lake County, California                    2540          940           15
# Los Angeles County, California            78132      1488626        25068
# Santa Barbara County, California           4941        24678          528
# Shasta County, California                  4420         5772          281
# Siskiyou County, California                1686          547          160
# Stanislaus County, California              4738        32003         3266
# Trinity County, California                  722          244           35
# Ventura County, California                 6990        61239         1943
#
#                                     B02001_007E  B02001_008E  B03001_003E
# Alameda County, California               184195       130496       369546  \
# Alpine County, California                     5          111          183
# Butte County, California                  11214        15608        37585
# Colusa County, California                  1369         2308        12840
# Contra Costa County, California          124647       104757       295791
# El Dorado County, California               4646         8659        24773
# Fresno County, California                143667        84357       528293
# Humboldt County, California                6017        10757        16228
# Imperial County, California               49175        19433       152880
# Kern County, California                  112122        75215       480700
# Kings County, California                  24230        13228        82954
# Lassen County, California                   840         1345         5893
# Madera County, California                 38486        11853        90958
# Marin County, California                  20845        17433        41737
# Mariposa County, California                 514          765         2041
# Mendocino County, California               4746         6565        22354
# Merced County, California                 84561        16931       164836
# Modoc County, California                    239          201         1317
# Monterey County, California              151957        29647       255512
# Napa County, California                   15647         9742        47300
# Nevada County, California                  1172         4484         9480
# Orange County, California                379652       217089      1071393
# Placer County, California                 10585        24914        55932
# Plumas County, California                   334          941         1749
# Riverside County, California             539108       190963      1204521
# Sacramento County, California            125950       140768       360204
# San Benito County, California              6217         7315        37015
# San Bernardino County, California        386398       202057      1163038
# San Diego County, California             223588       286106      1126266
# San Francisco County, California          67358        62702       132865
# San Joaquin County, California            76400       106196       313385
# San Luis Obispo County, California        12435        18720        64275
# San Mateo County, California              81350        57690       184490
# Santa Clara County, California           189968       143857       482101
# Santa Cruz County, California             38978        19184        91876
# Sierra County, California                    88           16          293
# Solano County, California                 41038        41339       119294
# Sonoma County, California                 66089        34952       134024
# Sutter County, California                  5950         9518        30101
# Tehama County, California                  3344         4452        16435
# Tulare County, California                 85508        37160       301919
# Tuolumne County, California                1599         2789         6810
# Yolo County, California                   12433        21326        69341
# Yuba County, California                    3370         7561        22318
# Mono County, California                     667          641         3893
# Amador County, California                  1537         2834         5591
# Calaveras County, California               1008         2912         5710
# Del Norte County, California               1910         2160         5552
# Glenn County, California                   2958          886        11828
# Inyo County, California                     491         1398         4115
# Lake County, California                    7252         3234        13667
# Los Angeles County, California          2113852       729532      4851344
# Santa Barbara County, California          43441        43286       203207
# Shasta County, California                  3925        10371        18566
# Siskiyou County, California                 826         3434         5605
# Stanislaus County, California             56972        47592       256424
# Trinity County, California                  449          332          933
# Ventura County, California                50425        71894       361648
#
#                                     B19013_001E   FIPS
# Alameda County, California               104888  06001
# Alpine County, California                 85750  06003
# Butte County, California                  54972  06007
# Colusa County, California                 59427  06011
# Contra Costa County, California          103997  06013
# El Dorado County, California              83710  06017
# Fresno County, California                 57109  06019
# Humboldt County, California               49235  06023
# Imperial County, California               46222  06025
# Kern County, California                   54851  06029
# Kings County, California                  61556  06031
# Lassen County, California                 56971  06035
# Madera County, California                 61924  06039
# Marin County, California                 121671  06041
# Mariposa County, California               50960  06043
# Mendocino County, California              52915  06045
# Merced County, California                 56330  06047
# Modoc County, California                  51250  06049
# Monterey County, California               76943  06053
# Napa County, California                   92219  06055
# Nevada County, California                 68333  06057
# Orange County, California                 94441  06059
# Placer County, California                 93677  06061
# Plumas County, California                 57233  06063
# Riverside County, California              70732  06065
# Sacramento County, California             70684  06067
# San Benito County, California             85808  06069
# San Bernardino County, California         65761  06071
# San Diego County, California              82426  06073
# San Francisco County, California         119136  06075
# San Joaquin County, California            68628  06077
# San Luis Obispo County, California        77948  06079
# San Mateo County, California             128091  06081
# Santa Clara County, California           130890  06085
# Santa Cruz County, California             89986  06087
# Sierra County, California                 52103  06091
# Solano County, California                 84638  06095
# Sonoma County, California                 86173  06097
# Sutter County, California                 63502  06101
# Tehama County, California                 48895  06103
# Tulare County, California                 52534  06107
# Tuolumne County, California               60509  06109
# Yolo County, California                   73746  06113
# Yuba County, California                   59424  06115
# Mono County, California                   64924  06051
# Amador County, California                 65187  06005
# Calaveras County, California              67054  06009
# Del Norte County, California              49981  06015
# Glenn County, California                  51682  06021
# Inyo County, California                   59296  06027
# Lake County, California                   49254  06033
# Los Angeles County, California            71358  06037
# Santa Barbara County, California          78925  06083
# Shasta County, California                 57139  06089
# Siskiyou County, California               47403  06093
# Stanislaus County, California             62873  06099
# Trinity County, California                41780  06105
# Ventura County, California                89295  06111

# %% [markdown]
# Let's see if we can do the same for ACS1

# %%
def query_ACS1(year):
    '''
    query race, ethnicity, and income data from ACS1 for years ranging from 2010 to 2021
    
    Args:
        year: an integer between 2010 and 2021
        
    Returns:
        a pandas dataframe
    '''
    
    # Define the desired variables
    variables = [
        'B01003_001E',  # Total population
        'B02001_002E',  # Total population - White alone
        'B02001_003E',  # Total population - Black or African American alone
        'B02001_004E',  # Total population - American Indian and Alaska Native alone
        'B02001_005E',  # Total population - Asian alone
        'B02001_006E',  # Total population - Native Hawaiian and Other Pacific Islander alone
        'B02001_007E',  # Total population - Some other race alone
        'B02001_008E',  # Total population - Two or more races
        'B03001_003E',  # Total population - Hispanic or Latino
        'B19013_001E',  # Median household income
    ]

    # Set the state to California
    state = '06'

    # Get all county codes for California
    counties = censusdata.geographies(censusdata.censusgeo([('state', state), ('county', '*')]), "acs1", year = year)

    # Query data for each county
    data = censusdata.download('acs1', year, censusdata.censusgeo([('state', state), ('county', '*')]), variables)

    county_name = list(range(len(data.index)))
    FIPS = list(range(len(data.index)))
    i = 0
    for county_code, county_data in data.iterrows():
        county_name[i] = [k for k,v in counties.items() if v == county_code][0]
        FIPS[i] = county_code.params()[0][1] + county_code.params()[1][1]
        i += 1
    
    data.index = county_name
    data["FIPS"] = FIPS
    
    return data

# %%
data = query_ACS1(2021)
data
# Out:
#                                     B01003_001E  B02001_002E  B02001_003E
# Kings County, California                 153443        55481        10751  \
# Los Angeles County, California          9829544      2909096       745491
# Napa County, California                  136207        76435         2643
# Orange County, California               3167809      1361528        57685
# Riverside County, California            2458395       887331       158186
# San Bernardino County, California       2194710       723292       173834
# San Joaquin County, California           789410       246993        52965
# Santa Barbara County, California         446475       211877         8528
# Shasta County, California                182139       142473         2231
# Solano County, California                451716       174831        57039
# Stanislaus County, California            552999       230860        15738
# Ventura County, California               839784       441352        14415
# Madera County, California                159410        60686         4027
# Marin County, California                 260206       181285         5810
# Mendocino County, California              91305        58663         1172
# Merced County, California                286461        86433         8665
# Monterey County, California              437325       139727        10290
# Nevada County, California                103487        85926          343
# Placer County, California                412300       290804         5842
# Sacramento County, California           1588921       710255       157690
# San Benito County, California             66677        23970          355
# San Diego County, California            3286069      1574281       154666
# San Francisco County, California         815201       317763        42989
# San Luis Obispo County, California       283159       198073         3502
# San Mateo County, California             737888       287091        17491
# Santa Clara County, California          1885508       573548        45968
# Santa Cruz County, California            267792       154786         2415
# Sonoma County, California                485887       309810         7725
# Sutter County, California                 99063        42278         1528
# Tehama County, California                 65498        46273          956
# Tulare County, California                477054       178557         7693
# Yolo County, California                  216986       108891         6048
# Yuba County, California                   83421        42651         3398
# Lake County, California                   68766        47729         1468
# Alameda County, California              1648556       507237       161520
# Butte County, California                 208309       150199         4104
# Contra Costa County, California         1161413       497712       101061
# El Dorado County, California             193221       147391         1509
# Fresno County, California               1013581       336394        43869
# Humboldt County, California              136310        95569         1620
# Imperial County, California              179851        30270         4984
# Kern County, California                  917673       414385        47015
#
#                                     B02001_004E  B02001_005E  B02001_006E
# Kings County, California                   2974         6237          683  \
# Los Angeles County, California           168537      1455775        22961
# Napa County, California                    2417        12092          140
# Orange County, California                 28359       701307         8747
# Riverside County, California              26026       164980         8665
# San Bernardino County, California         38649       176441         8377
# San Joaquin County, California            10294       146867         5773
# Santa Barbara County, California           5975        23983          843
# Shasta County, California                  3123         6098           95
# Solano County, California                  2554        72676         3659
# Stanislaus County, California              9842        32536         3730
# Ventura County, California                19122        61695         1442
# Madera County, California                  1973         3454          295
# Marin County, California                   1430        17472          704
# Mendocino County, California               3395         2073          277
# Merced County, California                  3918        21723          630
# Monterey County, California                2800        26313         2056
# Nevada County, California                   357         2584            0
# Placer County, California                  1805        34287          277
# Sacramento County, California             15943       272825        18052
# San Benito County, California               873         2154          722
# San Diego County, California              38916       395550        13005
# San Francisco County, California           3912       289622         2644
# San Luis Obispo County, California         1984         9632          603
# San Mateo County, California               9397       230827         9516
# Santa Clara County, California            16914       742426         8046
# Santa Cruz County, California              5252        13072            0
# Sonoma County, California                  7878        22541         2275
# Sutter County, California                  2401        15844         1253
# Tehama County, California                  1158         1199          102
# Tulare County, California                  7649        18376         1048
# Yolo County, California                    2184        33082          568
# Yuba County, California                    2560         6833          303
# Lake County, California                    1329         1080          681
# Alameda County, California                16177       538681        13608
# Butte County, California                   2582        11301          651
# Contra Costa County, California           14838       212648         5438
# El Dorado County, California               1620        11062           36
# Fresno County, California                 12992       110995         1789
# Humboldt County, California                7853         4685          486
# Imperial County, California                3567         3048           28
# Kern County, California                   11859        45257         1566
#
#                                     B02001_007E  B02001_008E  B03001_003E
# Kings County, California                  40899        36418          NaN  \
# Los Angeles County, California          2547028      1980656    4824989.0
# Napa County, California                   19123        23357          NaN
# Orange County, California                491135       519048    1080593.0
# Riverside County, California             702249       510958    1267615.0
# San Bernardino County, California        619332       454785    1224685.0
# San Joaquin County, California           147491       179027          NaN
# Santa Barbara County, California          78016       117253     210764.0
# Shasta County, California                  5601        22518          NaN
# Solano County, California                 68494        72463     129083.0
# Stanislaus County, California            102027       158266          NaN
# Ventura County, California                91357       210401     369992.0
# Madera County, California                 52423        36552          NaN
# Marin County, California                  24195        29310          NaN
# Mendocino County, California              11850        13875          NaN
# Merced County, California                128147        36945          NaN
# Monterey County, California              192775        63364          NaN
# Nevada County, California                  3125        11152          NaN
# Placer County, California                 23104        56181      62673.0
# Sacramento County, California            184039       230117     387454.0
# San Benito County, California             12720        25883          NaN
# San Diego County, California             391847       717804    1145183.0
# San Francisco County, California          62933        95338     128030.0
# San Luis Obispo County, California        18846        50519          NaN
# San Mateo County, California              84489        99077     176847.0
# Santa Clara County, California           200753       297853     471518.0
# Santa Cruz County, California             49012        43255          NaN
# Sonoma County, California                 68072        67586     137610.0
# Sutter County, California                 17150        18609          NaN
# Tehama County, California                  4043        11767          NaN
# Tulare County, California                126273       137458          NaN
# Yolo County, California                   26229        39984          NaN
# Yuba County, California                   11013        16663          NaN
# Lake County, California                    7479         9000          NaN
# Alameda County, California               219426       191907     369668.0
# Butte County, California                  10786        28686          NaN
# Contra Costa County, California          155515       174201     310805.0
# El Dorado County, California               8979        22624          NaN
# Fresno County, California                219670       287872     554633.0
# Humboldt County, California                5900        20197          NaN
# Imperial County, California               89216        48738          NaN
# Kern County, California                  164922       232669          NaN
#
#                                     B19013_001E   FIPS
# Kings County, California                  62155  06031
# Los Angeles County, California            77456  06037
# Napa County, California                   97213  06055
# Orange County, California                100559  06059
# Riverside County, California              79024  06065
# San Bernardino County, California         74846  06071
# San Joaquin County, California            80681  06077
# Santa Barbara County, California          84846  06083
# Shasta County, California                 61125  06089
# Solano County, California                 87770  06095
# Stanislaus County, California             73982  06099
# Ventura County, California                96454  06111
# Madera County, California                 63454  06039
# Marin County, California                 118209  06041
# Mendocino County, California              59444  06045
# Merced County, California                 53992  06047
# Monterey County, California               82163  06053
# Nevada County, California                 79519  06057
# Placer County, California                103659  06061
# Sacramento County, California             80063  06067
# San Benito County, California            101923  06069
# San Diego County, California              91003  06073
# San Francisco County, California         121826  06075
# San Luis Obispo County, California        80615  06079
# San Mateo County, California             131796  06081
# Santa Clara County, California           141562  06085
# Santa Cruz County, California             93933  06087
# Sonoma County, California                 94295  06097
# Sutter County, California                 64251  06101
# Tehama County, California                 48810  06103
# Tulare County, California                 58209  06107
# Yolo County, California                   78146  06113
# Yuba County, California                   63303  06115
# Lake County, California                   61221  06033
# Alameda County, California               109729  06001
# Butte County, California                  64738  06007
# Contra Costa County, California          111080  06013
# El Dorado County, California              87491  06017
# Fresno County, California                 63656  06019
# Humboldt County, California               54752  06023
# Imperial County, California               51809  06025
# Kern County, California                   58217  06029

# %% [markdown]
# # 2. Creating Visualizations of Demographic Groups
