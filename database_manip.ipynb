# %%
sql_database = 'airpandas.sqlite'

# %%
import sqlite3

def get_column_names(table_name, sql_database):
    # Establish a connection to the database
    conn = sqlite3.connect(sql_database)

    # Create a cursor object
    cur = conn.cursor()

    # Execute the PRAGMA table_info command
    cur.execute(f"PRAGMA table_info({table_name})")

    # Fetch all rows of a query result
    rows = cur.fetchall()

    # Close the connection
    conn.close()

    # Return the column names. The column name is the second element in each row.
    return [row[1] for row in rows]

# %%
table_name = 'Race'
column_names = get_column_names(table_name, sql_database)
print(column_names)
# Out:
# ['NAME', 'est_total_population', 'pct_total_population', 'est_one_race', 'pct_one_race', 'est_white', 'pct_white', 'est_black_or_african', 'pct_black_or_african', 'est_american_indian', 'pct_american_indian', 'est_asian', 'pct_asian', 'est_native_hawaiian', 'pct_native_hawaiian', 'est_some_other_race', 'pct_some_other_race', 'est_two_or_more', 'pct_two_or_more', 'state', 'county', 'Year', 'FIPS']

# %%
from database_utils import get_all_tables, get_column_names, query_table

sql_database = 'airpandas.sqlite'
table_name = 'PM25'
start_date = "2010-01-01"
end_date = "2010-01-07"
fips = '06037'

# Get all tables in the database
tables = get_all_tables(sql_database)
print(tables)

# Get all columns in a table
columns = get_column_names(table_name, sql_database)
print(columns)

# Query a table with a date range and a FIPS code
df = query_table(sql_database, table_name, columns, start_date, end_date, fips)
print(df)
# Out:
# ['Race', 'Income', 'Education', 'Employment', 'Heating', 'Occupation', 'Commute', 'Industry', 'Poverty', 'PM25']
# ['state_code', 'county_code', 'site_number', 'parameter_code', 'poc', 'latitude', 'longitude', 'datum', 'parameter', 'date_local', 'time_local', 'date_gmt', 'time_gmt', 'sample_measurement', 'units_of_measure', 'units_of_measure_code', 'sample_duration', 'sample_duration_code', 'sample_frequency', 'detection_limit', 'uncertainty', 'qualifier', 'method_type', 'method', 'method_code', 'state', 'county', 'date_of_last_change', 'cbsa_code', 'FIPS', 'year', 'month', 'day', 'measures']
#     state_code  county_code  site_number  parameter_code  poc   latitude  \
# 0            6           37         1103           88101    2  34.066590
# 1            6           37         4004           88101    1  33.792360
# 2            6           37         1201           88101    1  34.199250
# 3            6           37         1201           88101    1  34.199250
# 4            6           37            2           88101    1  34.136500
# 5            6           37            2           88101    1  34.136500
# 6            6           37         1602           88101    1  34.010290
# 7            6           37         1602           88101    1  34.010290
# 8            6           37         1302           88101    1  33.901389
# 9            6           37         1302           88101    1  33.901389
# 10           6           37         2005           88101    1  34.132600
# 11           6           37         2005           88101    1  34.132600
# 12           6           37         9033           88101    1  34.669739
# 13           6           37         9033           88101    1  34.669739
# 14           6           37         9033           88101    1  34.669739
# 15           6           37         1002           88101    1  34.176050
# 16           6           37         1002           88101    1  34.176050
# 17           6           37         1002           88101    1  34.176050
# 18           6           37         1002           88101    1  34.176050
# 19           6           37         1002           88101    1  34.176050
# 20           6           37         1002           88101    1  34.176050
# 21           6           37         1103           88101    1  34.066590
# 22           6           37         1103           88101    1  34.066590
# 23           6           37         1103           88101    1  34.066590
# 24           6           37         1103           88101    1  34.066590
# 25           6           37         1103           88101    1  34.066590
# 26           6           37         1103           88101    1  34.066590
# 27           6           37         4004           88101    1  33.792360
# 28           6           37         4004           88101    1  33.792360
# 29           6           37         4004           88101    1  33.792360
# 30           6           37         4004           88101    1  33.792360
# 31           6           37         4004           88101    1  33.792360
# 32           6           37         4002           88101    1  33.823760
# 33           6           37         4002           88101    1  33.823760
# 34           6           37         4002           88101    1  33.823760
# 35           6           37         4002           88101    1  33.823760
# 36           6           37         4002           88101    1  33.823760
# 37           6           37         4002           88101    1  33.823760
#
#      longitude  datum                 parameter                  date_local  \
# 0  -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 1  -118.175330  WGS84  PM2.5 - Local Conditions  2010-01-06 00:00:00.000000
# 2  -118.532760  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 3  -118.532760  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 4  -117.923910  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 5  -117.923910  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 6  -118.068500  NAD83  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 7  -118.068500  NAD83  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 8  -118.205000  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 9  -118.205000  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 10 -118.127200  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 11 -118.127200  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 12 -118.130511  NAD83  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 13 -118.130511  NAD83  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 14 -118.130511  NAD83  PM2.5 - Local Conditions  2010-01-06 00:00:00.000000
# 15 -118.317120  WGS84  PM2.5 - Local Conditions  2010-01-01 00:00:00.000000
# 16 -118.317120  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 17 -118.317120  WGS84  PM2.5 - Local Conditions  2010-01-03 00:00:00.000000
# 18 -118.317120  WGS84  PM2.5 - Local Conditions  2010-01-04 00:00:00.000000
# 19 -118.317120  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 20 -118.317120  WGS84  PM2.5 - Local Conditions  2010-01-06 00:00:00.000000
# 21 -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-06 00:00:00.000000
# 22 -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-01 00:00:00.000000
# 23 -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 24 -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-03 00:00:00.000000
# 25 -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-04 00:00:00.000000
# 26 -118.226880  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 27 -118.175330  WGS84  PM2.5 - Local Conditions  2010-01-01 00:00:00.000000
# 28 -118.175330  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 29 -118.175330  WGS84  PM2.5 - Local Conditions  2010-01-03 00:00:00.000000
# 30 -118.175330  WGS84  PM2.5 - Local Conditions  2010-01-04 00:00:00.000000
# 31 -118.175330  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 32 -118.189210  WGS84  PM2.5 - Local Conditions  2010-01-04 00:00:00.000000
# 33 -118.189210  WGS84  PM2.5 - Local Conditions  2010-01-01 00:00:00.000000
# 34 -118.189210  WGS84  PM2.5 - Local Conditions  2010-01-02 00:00:00.000000
# 35 -118.189210  WGS84  PM2.5 - Local Conditions  2010-01-03 00:00:00.000000
# 36 -118.189210  WGS84  PM2.5 - Local Conditions  2010-01-05 00:00:00.000000
# 37 -118.189210  WGS84  PM2.5 - Local Conditions  2010-01-06 00:00:00.000000
#
#     ... method_code       state       county  date_of_last_change cbsa_code  \
# 0   ...         120  California  Los Angeles           2011-04-06   31080.0
# 1   ...         120  California  Los Angeles           2011-05-17   31080.0
# 2   ...         120  California  Los Angeles           2011-04-06   31080.0
# 3   ...         120  California  Los Angeles           2011-04-06   31080.0
# 4   ...         120  California  Los Angeles           2011-04-06   31080.0
# 5   ...         120  California  Los Angeles           2011-04-06   31080.0
# 6   ...         120  California  Los Angeles           2011-04-06   31080.0
# 7   ...         120  California  Los Angeles           2011-04-06   31080.0
# 8   ...         120  California  Los Angeles           2011-04-06   31080.0
# 9   ...         120  California  Los Angeles           2011-04-06   31080.0
# 10  ...         120  California  Los Angeles           2011-04-06   31080.0
# 11  ...         120  California  Los Angeles           2011-04-06   31080.0
# 12  ...         117  California  Los Angeles           2011-08-17   31080.0
# 13  ...         117  California  Los Angeles           2011-08-17   31080.0
# 14  ...         117  California  Los Angeles           2011-08-17   31080.0
# 15  ...         120  California  Los Angeles           2011-05-17   31080.0
# 16  ...         120  California  Los Angeles           2011-05-17   31080.0
# 17  ...         120  California  Los Angeles           2011-05-17   31080.0
# 18  ...         120  California  Los Angeles           2011-05-17   31080.0
# 19  ...         120  California  Los Angeles           2011-05-17   31080.0
# 20  ...         120  California  Los Angeles           2011-05-17   31080.0
# 21  ...         120  California  Los Angeles           2011-05-17   31080.0
# 22  ...         120  California  Los Angeles           2011-05-17   31080.0
# 23  ...         120  California  Los Angeles           2011-05-17   31080.0
# 24  ...         120  California  Los Angeles           2011-05-17   31080.0
# 25  ...         120  California  Los Angeles           2011-05-17   31080.0
# 26  ...         120  California  Los Angeles           2011-05-17   31080.0
# 27  ...         120  California  Los Angeles           2011-05-17   31080.0
# 28  ...         120  California  Los Angeles           2011-05-17   31080.0
# 29  ...         120  California  Los Angeles           2011-05-17   31080.0
# 30  ...         120  California  Los Angeles           2011-05-17   31080.0
# 31  ...         120  California  Los Angeles           2011-05-17   31080.0
# 32  ...         120  California  Los Angeles           2011-05-17   31080.0
# 33  ...         120  California  Los Angeles           2011-05-17   31080.0
# 34  ...         120  California  Los Angeles           2011-05-17   31080.0
# 35  ...         120  California  Los Angeles           2011-05-17   31080.0
# 36  ...         120  California  Los Angeles           2011-05-17   31080.0
# 37  ...         120  California  Los Angeles           2011-05-17   31080.0
#
#      FIPS  year  month day  measures
# 0   06037  2010      1   2       112
# 1   06037  2010      1   6        95
# 2   06037  2010      1   5        30
# 3   06037  2010      1   2        30
# 4   06037  2010      1   5        30
# 5   06037  2010      1   2        30
# 6   06037  2010      1   2        30
# 7   06037  2010      1   5        30
# 8   06037  2010      1   2        30
# 9   06037  2010      1   5        30
# 10  06037  2010      1   2        30
# 11  06037  2010      1   5        30
# 12  06037  2010      1   2        16
# 13  06037  2010      1   5        16
# 14  06037  2010      1   6        16
# 15  06037  2010      1   1       104
# 16  06037  2010      1   2       104
# 17  06037  2010      1   3       104
# 18  06037  2010      1   4       104
# 19  06037  2010      1   5       104
# 20  06037  2010      1   6       104
# 21  06037  2010      1   6       142
# 22  06037  2010      1   1       142
# 23  06037  2010      1   2       142
# 24  06037  2010      1   3       142
# 25  06037  2010      1   4       142
# 26  06037  2010      1   5       142
# 27  06037  2010      1   1        86
# 28  06037  2010      1   2        86
# 29  06037  2010      1   3        86
# 30  06037  2010      1   4        86
# 31  06037  2010      1   5        86
# 32  06037  2010      1   4        94
# 33  06037  2010      1   1        94
# 34  06037  2010      1   2        94
# 35  06037  2010      1   3        94
# 36  06037  2010      1   5        94
# 37  06037  2010      1   6        94
#
# [38 rows x 34 columns]
